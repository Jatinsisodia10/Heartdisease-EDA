# %%
import os
import numpy as np 
import pandas as pd 
import seaborn as sns
import warnings

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/heart-disease-eda/heart.csv

# %%
warnings.filterwarnings("ignore")

# %%
df =  pd.read_csv("/kaggle/input/heart-disease-eda/heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ## 1. Distribution for numeric cloumns

# %%
sns.displot(df["Age"])

# %%
sns.displot(df["Age"], kde  = True, color = "red")

# %%
sns.displot(df["RestingBP"], kde  = True, color = "green")

# %%
sns.displot(df["Cholesterol"], kde  = True, color = "black")

# %%
sns.displot(df["MaxHR"], kde  = True, color = "blue")

# %% [markdown]
# ## 2. Pie chart for categorical

# %%
df.groupby("Sex").size().plot(kind = "pie", autopct = "%.1f")
# Out:
# <Axes: >

# %%
df.groupby("ChestPainType").size().plot(kind = "pie", autopct = "%.1f")
# Out:
# <Axes: >

# %%
df.groupby("RestingECG").size().plot(kind = "pie", autopct = "%.1f")
# Out:
# <Axes: >

# %%
df.groupby("ST_Slope").size().plot(kind = "pie", autopct = "%.1f")
# Out:
# <Axes: >

# %%
df.groupby("ExerciseAngina").size().plot(kind = "pie", autopct = "%.1f")
# Out:
# <Axes: >

# %%
df.groupby("HeartDisease").size().plot(kind = "pie", autopct = "%.1f")
# Out:
# <Axes: >

# %% [markdown]
# ## 3. ViolinPlot Chart

# %%
sns.violinplot(y = df["Sex"], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y = df["Age"], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.violinplot(y = df["Cholesterol"], x = df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# ## 4. correlation

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df = numeric_df.dropna()
correlation_matrix = numeric_df.corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Jointplot

# %%
sns.jointplot(x = "Age", y = "MaxHR", data = df)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.jointplot(x = "Cholesterol", y = "Age", data = df, kind = "hex")

# %%
sns.jointplot(x = "Cholesterol", y = "Age", data = df, kind = "reg")

# %% [markdown]
# ## 6. Pairplot

# %%
sns.pairplot(df)
